# %%
import os
import pandas as pd

base_dir = "/Users/natika/Downloads/past semesters/CHN-Project/BoS (Business Objects) Raw Data Reports - Deidentified/" 
program_ids = ["143", "1371 FINAL", "8319", "11495", "Erin Park", "MC PATH", "OC PATH", "SPC"]

# %%
for program_id in program_ids:
    file_path = f"{base_dir}{program_id} RAW Client Data Export v3_EE Workflow.xlsx"
    
    if "TEMPLATE" in file_path.upper():
        print(f"\nSkipping template file: {file_path}")
        continue

    if not os.path.exists(file_path):
        print(f"\nWarning: File not found for program {program_id}: {file_path}")
        continue

    print(f"\nProcessing program: {program_id}")

    try:
        all_sheets = pd.read_excel(file_path, sheet_name=None)

        for sheet_name, df in all_sheets.items():
            print(f"\n--- Program: {program_id} | Sheet: {sheet_name} ---")
            print(df.head(3))

    except Exception as e:
        print(f"Error processing {file_path}: {e}")

# %% [markdown]
# ### Number of clients who exited to permanent housing

# %%
target_column = 'Housing Move-in Date(12855)'

for program_id in program_ids:
    file_path = f"{base_dir}{program_id} RAW Client Data Export v3_EE Workflow.xlsx"
    
    if not os.path.exists(file_path):
        print(f"File not found for program {program_id}")
        continue

    try:
        df = pd.read_excel(file_path, sheet_name="ENTRY-EXIT", dtype=str)
        total_clients = len(df)

        if target_column not in df.columns:
            print(f"Program: {program_id} | Column '{target_column}' not found.")
            continue

        num_permanent_housing = df[target_column].dropna().loc[lambda x: x.str.strip() != ''].count()

        print(f"Program: {program_id} | Total clients: {total_clients} | Exited to permanent housing: {num_permanent_housing}")

    except Exception as e:
        print(f"Error processing {program_id}: {e}")

# %% [markdown]
# ### Breakdown of exit destinations (permanent housing, shelter, streets, etc.)

# %%
destination_col = 'Destination'

for program_id in program_ids:
    file_path = f"{base_dir}{program_id} RAW Client Data Export v3_EE Workflow.xlsx"

    if not os.path.exists(file_path):
        print(f"File not found for program {program_id}")
        continue

    try:
        df = pd.read_excel(file_path, sheet_name="ENTRY-EXIT", dtype=str)

        if destination_col not in df.columns:
            print(f"Program: {program_id} | Column '{destination_col}' not found.")
            continue

        value_counts = df[destination_col].dropna().str.strip().value_counts()

        print(f"\nProgram: {program_id} | Destination value counts:")
        print(value_counts.to_string())  # clean printout without index formatting

    except Exception as e:
        print(f"Error processing {program_id}: {e}")

# %%
destination_col = 'Destination'

# List to collect destination data
destination_results = []

for program_id in program_ids:
    file_path = f"{base_dir}{program_id} RAW Client Data Export v3_EE Workflow.xlsx"

    if not os.path.exists(file_path):
        print(f"File not found for program {program_id}")
        continue

    try:
        df = pd.read_excel(file_path, sheet_name="ENTRY-EXIT", dtype=str)

        if destination_col in df.columns:
            value_counts = df[destination_col].dropna().str.strip().value_counts()
            for destination, count in value_counts.items():
                destination_results.append({
                    "Program ID": program_id,
                    "Exit Destination": destination,
                    "Count": count
                })
        else:
            print(f"Program: {program_id} | Column '{destination_col}' not found.")

    except Exception as e:
        print(f"Error processing {program_id}: {e}")

# Convert to DataFrame
destination_df = pd.DataFrame(destination_results)

# Save to Excel
output_path = "destination_value_counts.xlsx"
destination_df.to_excel(output_path, sheet_name="Exit Destinations", index=False)

print(f"\n Exit destinations saved to: {output_path}")

# %%
movein_col = 'Housing Move-in Date(12855)'

# List to collect permanent housing counts
housing_movein_results = []

for program_id in program_ids:
    file_path = f"{base_dir}{program_id} RAW Client Data Export v3_EE Workflow.xlsx"

    if not os.path.exists(file_path):
        print(f"File not found for program {program_id}")
        continue

    try:
        df = pd.read_excel(file_path, sheet_name="ENTRY-EXIT", dtype=str)
        total_clients = len(df)

        if movein_col in df.columns:
            num_permanent = df[movein_col].dropna().loc[lambda x: x.str.strip() != ''].count()
            housing_movein_results.append({
                "Program ID": program_id,
                "Total Clients": total_clients,
                "Exited to Permanent Housing": num_permanent
            })
        else:
            print(f"Program: {program_id} | Column '{movein_col}' not found.")

    except Exception as e:
        print(f"Error processing {program_id}: {e}")

# Convert to DataFrame
housing_df = pd.DataFrame(housing_movein_results)

# Save to Excel
output_path = "permanent_housing_counts.xlsx"
housing_df.to_excel(output_path, sheet_name="Permanent Housing Counts", index=False)

print(f"\n Permanent housing counts saved to: {output_path}")

# %% [markdown]
# ### Average length of time to housing move-in

# %%
keywords = ["Rapid Rehousing Program", "Permanent Supportive Housing"]  

# Loop through each program
for program_id in program_ids:
    file_path = f"{base_dir}{program_id} RAW Client Data Export v3_EE Workflow.xlsx"
    
    if "TEMPLATE" in file_path.upper():
        continue
    if not os.path.exists(file_path):
        print(f"File not found for program {program_id}: {file_path}")
        continue

    try:
        # Read all sheets from the Excel file
        all_sheets = pd.read_excel(file_path, sheet_name=None, dtype=str)  # Read all sheets as strings

        # Loop through each sheet
        for sheet_name, df in all_sheets.items():
            print(f"Processing sheet: {sheet_name}...")  # Debugging output
            
            # Loop through each column in the sheet
            for col in df.columns:
                # Clean data by stripping any leading/trailing spaces
                df[col] = df[col].str.strip()

                # Check for rows that contain any of the keywords (whole phrases)
                matches = df[df[col].astype(str).str.contains('|'.join(keywords), case=False, na=False)]
                
                # Check if any matches are found
                if not matches.empty:
                    print(f"\n🔍 Match found!")
                    print(f"Program: {program_id}")
                    print(f"Sheet: {sheet_name}")
                    print(f"Column: {col}")
                    print(f"Rows matching any of the keywords {', '.join(keywords)}:")
                    print(matches[[col]].head(3))  # Show top 3 matching rows
                else:
                    print(f"No matches found in column: {col}")

    except Exception as e:
        print(f"Error processing {file_path}: {e}")
# Out:
# Processing sheet: Additional Info...
# No matches found in column: Unnamed: 0
#
# 🔍 Match found!
# Program: 143
# Sheet: Additional Info
# Column: Unnamed: 1
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                           Unnamed: 1
# 7  Community Housing Network, Inc. - Grafton SHU ...
# Processing sheet: CARF WORKSHEET...
# No matches found in column: Housing Status(6209)
# No matches found in column: Unnamed: 1
# No matches found in column: Total Homeless
# No matches found in column: 255
# No matches found in column: Unnamed: 4
# No matches found in column: Steps
# Processing sheet: ENTRY-EXIT...
#
# 🔍 Match found!
# Program: 143
# Sheet: ENTRY-EXIT
# Column: EE Provider ID
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                       EE Provider ID
# 0  Community Housing Network - Oakland County - R...
# 1  Community Housing Network - Oakland County - R...
# 2  Community Housing Network - Oakland County - R...
# No matches found in column: Entry Date
# No matches found in column: Housing Move-in Date(12855)
# No matches found in column: Exit Date
# No matches found in column: Destination
# No matches found in column: Reason for Leaving
# No matches found in column: Entry Exit Type
# No matches found in column: Entry Exit Date Added
# No matches found in column: Entry Exit User Creating
# No matches found in column: Entry Exit Date Updated
# No matches found in column: Entry Exit User Updating
# Processing sheet: EE REVIEWS...
#
# 🔍 Match found!
# Program: 143
# Sheet: EE REVIEWS
# Column: EE Provider ID
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                          EE Provider ID
# 3472  Community Housing Network - Oakland County - R...
# 3473  Community Housing Network - Oakland County - R...
# 3474  Community Housing Network - Oakland County - R...
# No matches found in column: Entry Exit Review Date
# No matches found in column: Entry Exit Review Point in Time Type
# No matches found in column: Entry Exit Review Type
#
# 🔍 Match found!
# Program: 143
# Sheet: EE REVIEWS
# Column: Entry Exit Review Provider Updating
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                     Entry Exit Review Provider Updating
# 3472  Community Housing Network - Oakland County - R...
# 3473  Community Housing Network - Oakland County - R...
# 3474  Community Housing Network - Oakland County - R...
# No matches found in column: Entry Exit Review Date Updated
# No matches found in column: Entry Exit Review User Updating
# Processing sheet: EE UDES...
#
# 🔍 Match found!
# Program: 143
# Sheet: EE UDES
# Column: EE Provider ID
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                         EE Provider ID
# 634  Community Housing Network - Oakland County - R...
# 635  Community Housing Network - Oakland County - R...
# 636  Community Housing Network - Oakland County - R...
# No matches found in column: Housing Status(6209)
# No matches found in column: Does the client have a disabling condition?(1139)
# No matches found in column: Survivor of Domestic Violence(341)
# No matches found in column: Enrollment CoC(10735)
# No matches found in column: City of Residence(1950)
# No matches found in column: County of Residence(1951)
# No matches found in column: Zip Code of Last Permanent Address(1136)
# No matches found in column: Prior Living Situation(43)
# No matches found in column: Length of Stay in Previous Place(1138)
# No matches found in column: On the night before did you stay on the streets, ES or SH?(12479)
# No matches found in column: Approximate date this episode of homelessness started(12480)
# No matches found in column: Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(12481)
# No matches found in column: Total number of months homeless on the street, in ES or SH in the past three years(12482)
# Processing sheet: INCOME ENT...
#
# 🔍 Match found!
# Program: 143
# Sheet: INCOME ENT
# Column: EE Provider ID
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                          EE Provider ID
# 7986  Community Housing Network - Oakland County - R...
# 7987  Community Housing Network - Oakland County - R...
# 7988  Community Housing Network - Oakland County - R...
# No matches found in column: Receiving Income (Entry)
# No matches found in column: Source of Income (Entry)
# No matches found in column: Monthly Income (Start)
# No matches found in column: Income Start Date (Entry)
# No matches found in column: Income End Date (Entry)
#
# 🔍 Match found!
# Program: 143
# Sheet: INCOME ENT
# Column: Provider (140-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (140-provider)
# 462  Community Housing Network - Oakland County - R...
# 464  Community Housing Network - Oakland County - R...
# 466  Community Housing Network - Oakland County - R...
# No matches found in column: Date Added (140-date_added)
# Processing sheet: INCOME EXT...
#
# 🔍 Match found!
# Program: 143
# Sheet: INCOME EXT
# Column: EE Provider ID
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                          EE Provider ID
# 8699  Community Housing Network - Oakland County - R...
# 8700  Community Housing Network - Oakland County - R...
# 8701  Community Housing Network - Oakland County - R...
# No matches found in column: Receiving Income (Exit)
# No matches found in column: Source of Income (Exit)
# No matches found in column: Monthly Income Amount (Exit)
# No matches found in column: Income Start Date (Exit)
# No matches found in column: Income End Date (Exit)
#
# 🔍 Match found!
# Program: 143
# Sheet: INCOME EXT
# Column: Provider (140-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (140-provider)
# 611  Community Housing Network - Oakland County - R...
# 614  Community Housing Network - Oakland County - R...
# 617  Community Housing Network - Oakland County - R...
# No matches found in column: Date Added (140-date_added)
# Processing sheet: NONCASH ENT...
#
# 🔍 Match found!
# Program: 143
# Sheet: NONCASH ENT
# Column: EE Provider ID
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                          EE Provider ID
# 3528  Community Housing Network - Oakland County - R...
# 3529  Community Housing Network - Oakland County - R...
# 3530  Community Housing Network - Oakland County - R...
# No matches found in column: Receiving Benefit (Entry)
# No matches found in column: Non-Cash Source (Entry)
# No matches found in column: Non-Cash Start Date (Entry)
# No matches found in column: Non-Cash End Date (Entry)
# Processing sheet: NONCASH EXIT...
#
# 🔍 Match found!
# Program: 143
# Sheet: NONCASH EXIT
# Column: EE Provider
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                             EE Provider
# 3832  Community Housing Network - Oakland County - R...
# 3833  Community Housing Network - Oakland County - R...
# 3834  Community Housing Network - Oakland County - R...
# No matches found in column: Receiving Benefit (Exit)
# No matches found in column: Non-Cash Source (Exit)
# No matches found in column: Non-Cash Amount (Exit)
# No matches found in column: Non-Cash Start Date (Exit)
# No matches found in column: Non-Cash End Date (Exit)
# Processing sheet: DISABILITY ENT...
#
# 🔍 Match found!
# Program: 143
# Sheet: DISABILITY ENT
# Column: EE Provider ID
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                          EE Provider ID
# 4909  Community Housing Network - Oakland County - R...
# 4910  Community Housing Network - Oakland County - R...
# 4911  Community Housing Network - Oakland County - R...
# No matches found in column: Disability Determination (Entry)
# No matches found in column: Disability Type (Entry)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Entry)
# No matches found in column: End Date(874)
#
# 🔍 Match found!
# Program: 143
# Sheet: DISABILITY ENT
# Column: Provider (417-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (417-provider)
# 280  Community Housing Network - Oakland County - R...
# 282  Community Housing Network - Oakland County - R...
# 283  Community Housing Network - Oakland County - R...
# No matches found in column: Date Added (417-date_added)
# Processing sheet: DISABILITY EXIT...
#
# 🔍 Match found!
# Program: 143
# Sheet: DISABILITY EXIT
# Column: EE Provider ID
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                          EE Provider ID
# 5441  Community Housing Network - Oakland County - R...
# 5442  Community Housing Network - Oakland County - R...
# 5443  Community Housing Network - Oakland County - R...
# No matches found in column: Disability Determination (Exit)
# No matches found in column: Disability Type (Exit)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Exit)
# No matches found in column: Disability End Date (Exit)
#
# 🔍 Match found!
# Program: 143
# Sheet: DISABILITY EXIT
# Column: Provider (417-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (417-provider)
# 391  Community Housing Network - Oakland County - R...
# 393  Community Housing Network - Oakland County - R...
# 395  Community Housing Network - Oakland County - R...
# No matches found in column: Date Added (417-date_added)
# Processing sheet: PROVIDER...
#
# 🔍 Match found!
# Program: 143
# Sheet: PROVIDER
# Column: EE Provider ID
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                         EE Provider ID
# 634  Community Housing Network - Oakland County - R...
# 635  Community Housing Network - Oakland County - R...
# 636  Community Housing Network - Oakland County - R...
# No matches found in column: CoC Code
#
# 🔍 Match found!
# Program: 143
# Sheet: PROVIDER
# Column: Program Type Code
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                      Program Type Code
# 157  PH - Permanent Supportive Housing (disability ...
# 158  PH - Permanent Supportive Housing (disability ...
# 159  PH - Permanent Supportive Housing (disability ...
# No matches found in column: Provider County
# Processing sheet: Additional Info...
# No matches found in column: Unnamed: 0
# No matches found in column: Unnamed: 1
# Processing sheet: ENTRY-EXIT...
# No matches found in column: EE Provider ID
# No matches found in column: Entry Date
# No matches found in column: Housing Move-in Date(12855)
# No matches found in column: Exit Date
# No matches found in column: Destination
# No matches found in column: Reason for Leaving
# No matches found in column: Entry Exit Type
# No matches found in column: Entry Exit Date Added
# No matches found in column: Entry Exit User Creating
# No matches found in column: Entry Exit Date Updated
# No matches found in column: Entry Exit User Updating
# Processing sheet: EE REVIEWS...
# No matches found in column: EE Provider ID
# No matches found in column: Entry Exit Review Date
# No matches found in column: Entry Exit Review Point in Time Type
# No matches found in column: Entry Exit Review Type
# No matches found in column: Entry Exit Review Provider Updating
# No matches found in column: Entry Exit Review Date Updated
# No matches found in column: Entry Exit Review User Updating
# Processing sheet: EE UDES...
# No matches found in column: EE Provider ID
# No matches found in column: Relationship to Head of Household(10731)
# No matches found in column: Housing Status(6209)
# No matches found in column: Does the client have a disabling condition?(1139)
# No matches found in column: Survivor of Domestic Violence(341)
# No matches found in column: Enrollment CoC(10735)
# No matches found in column: City of Residence(1950)
# No matches found in column: County of Residence(1951)
# No matches found in column: Zip Code of Last Permanent Address(1136)
# No matches found in column: Prior Living Situation(43)
# No matches found in column: Length of Stay in Previous Place(1138)
# No matches found in column: On the night before did you stay on the streets, ES or SH?(12479)
# No matches found in column: Approximate date this episode of homelessness started(12480)
# No matches found in column: Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(12481)
# No matches found in column: Total number of months homeless on the street, in ES or SH in the past three years(12482)
# Processing sheet: INCOME ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Income (Entry)
# No matches found in column: Source of Income (Entry)
# No matches found in column: Monthly Income (Start)
# No matches found in column: Income Start Date (Entry)
# No matches found in column: Income End Date (Entry)
# No matches found in column: Provider (140-provider)
# No matches found in column: Date Added (140-date_added)
# Processing sheet: INCOME EXT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Income (Exit)
# No matches found in column: Source of Income (Exit)
# No matches found in column: Monthly Income Amount (Exit)
# No matches found in column: Income Start Date (Exit)
# No matches found in column: Income End Date (Exit)
# No matches found in column: Provider (140-provider)
# No matches found in column: Date Added (140-date_added)
# Processing sheet: NONCASH ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Benefit (Entry)
# No matches found in column: Non-Cash Source (Entry)
# No matches found in column: Non-Cash Start Date (Entry)
# No matches found in column: Non-Cash End Date (Entry)
# Processing sheet: NONCASH EXIT...
# No matches found in column: EE Provider
# No matches found in column: Receiving Benefit (Exit)
# No matches found in column: Non-Cash Source (Exit)
# No matches found in column: Non-Cash Amount (Exit)
# No matches found in column: Non-Cash Start Date (Exit)
# No matches found in column: Non-Cash End Date (Exit)
# Processing sheet: DISABILITY ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Disability Determination (Entry)
# No matches found in column: Disability Type (Entry)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Entry)
# No matches found in column: End Date(874)
# No matches found in column: Provider (417-provider)
# No matches found in column: Date Added (417-date_added)
# Processing sheet: DISABILITY EXIT...
# No matches found in column: EE Provider ID
# No matches found in column: Disability Determination (Exit)
# No matches found in column: Disability Type (Exit)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Exit)
# No matches found in column: Disability End Date (Exit)
# No matches found in column: Provider (417-provider)
# No matches found in column: Date Added (417-date_added)
# Processing sheet: PROVIDER...
# No matches found in column: EE Provider ID
# No matches found in column: CoC Code
#
# 🔍 Match found!
# Program: 1371 FINAL
# Sheet: PROVIDER
# Column: Program Type Code
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                    Program Type Code
# 0  PH - Permanent Supportive Housing (disability ...
# 1  PH - Permanent Supportive Housing (disability ...
# 2  PH - Permanent Supportive Housing (disability ...
# No matches found in column: Provider County
# Processing sheet: Additional Info...
# No matches found in column: Unnamed: 0
# No matches found in column: Unnamed: 1
# Processing sheet: ENTRY-EXIT...
# No matches found in column: EE Provider ID
# No matches found in column: Entry Date
# No matches found in column: Housing Move-in Date(12855)
# No matches found in column: Exit Date
# No matches found in column: Destination
# No matches found in column: Reason for Leaving
# No matches found in column: Entry Exit Type
# No matches found in column: Entry Exit Date Added
# No matches found in column: Entry Exit User Creating
# No matches found in column: Entry Exit Date Updated
# No matches found in column: Entry Exit User Updating
# Processing sheet: EE REVIEWS...
# No matches found in column: EE Provider ID
# No matches found in column: Entry Exit Review Point in Time Type
# No matches found in column: Entry Exit Review Type
#
# 🔍 Match found!
# Program: 8319
# Sheet: EE REVIEWS
# Column: Entry Exit Review Provider Updating
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                   Entry Exit Review Provider Updating
# 84  Community Housing Network - Oakland County - R...
# 85  Community Housing Network - Oakland County - R...
# 86  Community Housing Network - Oakland County - R...
# No matches found in column: Entry Exit Review Date Updated
# No matches found in column: Entry Exit Review User Updating
# Processing sheet: EE UDES...
# No matches found in column: EE Provider ID
# No matches found in column: Relationship to Head of Household(10731)
# No matches found in column: Housing Status(6209)
# No matches found in column: Does the client have a disabling condition?(1139)
# No matches found in column: Survivor of Domestic Violence(341)
# No matches found in column: Enrollment CoC(10735)
# No matches found in column: City of Residence(1950)
# No matches found in column: County of Residence(1951)
# No matches found in column: Zip Code of Last Permanent Address(1136)
# No matches found in column: Prior Living Situation(43)
# No matches found in column: Length of Stay in Previous Place(1138)
# No matches found in column: On the night before did you stay on the streets, ES or SH?(12479)
# No matches found in column: Approximate date this episode of homelessness started(12480)
# No matches found in column: Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(12481)
# No matches found in column: Total number of months homeless on the street, in ES or SH in the past three years(12482)
# Processing sheet: INCOME ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Income (Entry)
# No matches found in column: Source of Income (Entry)
# No matches found in column: Monthly Income (Start)
# No matches found in column: Income Start Date (Entry)
# No matches found in column: Income End Date (Entry)
#
# 🔍 Match found!
# Program: 8319
# Sheet: INCOME ENT
# Column: Provider (140-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (140-provider)
# 549  XXXCLOSED2019 - Community Housing Network - Oa...
# 551  XXXCLOSED2019 - Community Housing Network - Oa...
# 553  XXXCLOSED2019 - Community Housing Network - Oa...
# No matches found in column: Date Added (140-date_added)
# Processing sheet: INCOME EXT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Income (Exit)
# No matches found in column: Source of Income (Exit)
# No matches found in column: Monthly Income Amount (Exit)
# No matches found in column: Income Start Date (Exit)
# No matches found in column: Income End Date (Exit)
#
# 🔍 Match found!
# Program: 8319
# Sheet: INCOME EXT
# Column: Provider (140-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (140-provider)
# 14   Community Housing Network - Oakland County - R...
# 551  XXXCLOSED2019 - Community Housing Network - Oa...
# 553  XXXCLOSED2019 - Community Housing Network - Oa...
# No matches found in column: Date Added (140-date_added)
# Processing sheet: NONCASH ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Benefit (Entry)
# No matches found in column: Non-Cash Source (Entry)
# No matches found in column: Non-Cash Start Date (Entry)
# No matches found in column: Non-Cash End Date (Entry)
# Processing sheet: NONCASH EXIT...
# No matches found in column: EE Provider
# No matches found in column: Receiving Benefit (Exit)
# No matches found in column: Non-Cash Source (Exit)
# No matches found in column: Non-Cash Amount (Exit)
# No matches found in column: Non-Cash Start Date (Exit)
# No matches found in column: Non-Cash End Date (Exit)
# Processing sheet: DISABILITY ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Disability Determination (Entry)
# No matches found in column: Disability Type (Entry)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Entry)
# No matches found in column: End Date(874)
#
# 🔍 Match found!
# Program: 8319
# Sheet: DISABILITY ENT
# Column: Provider (417-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                 Provider (417-provider)
# 2206  XXXCLOSED2019 - Community Housing Network - Oa...
# 2208  XXXCLOSED2019 - Community Housing Network - Oa...
# 2210  XXXCLOSED2019 - Community Housing Network - Oa...
# No matches found in column: Date Added (417-date_added)
# Processing sheet: DISABILITY EXIT...
# No matches found in column: EE Provider ID
# No matches found in column: Disability Determination (Exit)
# No matches found in column: Disability Type (Exit)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Exit)
# No matches found in column: Disability End Date (Exit)
#
# 🔍 Match found!
# Program: 8319
# Sheet: DISABILITY EXIT
# Column: Provider (417-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                 Provider (417-provider)
# 2357  XXXCLOSED2019 - Community Housing Network - Oa...
# 2359  XXXCLOSED2019 - Community Housing Network - Oa...
# 2361  XXXCLOSED2019 - Community Housing Network - Oa...
# No matches found in column: Date Added (417-date_added)
# Processing sheet: PROVIDER...
# No matches found in column: EE Provider ID
# No matches found in column: CoC Code
# No matches found in column: Program Type Code
# No matches found in column: Provider County
# Processing sheet: Additional Info...
# No matches found in column: Unnamed: 0
# No matches found in column: Unnamed: 1
# Processing sheet: ENTRY-EXIT...
# No matches found in column: EE Provider ID
# No matches found in column: Entry Date
# No matches found in column: Housing Move-in Date(12855)
# No matches found in column: Exit Date
# No matches found in column: Destination
# No matches found in column: Reason for Leaving
# No matches found in column: Entry Exit Type
# No matches found in column: Entry Exit Date Added
# No matches found in column: Entry Exit User Creating
# No matches found in column: Entry Exit Date Updated
# No matches found in column: Entry Exit User Updating
# Processing sheet: EE REVIEWS...
# No matches found in column: EE Provider ID
# No matches found in column: Entry Exit Review Point in Time Type
# No matches found in column: Entry Exit Review Type
# No matches found in column: Entry Exit Review Provider Updating
# No matches found in column: Entry Exit Review Date Updated
# No matches found in column: Entry Exit Review User Updating
# Processing sheet: EE UDES...
# No matches found in column: EE Provider ID
# No matches found in column: Relationship to Head of Household(10731)
# No matches found in column: Housing Status(6209)
# No matches found in column: Does the client have a disabling condition?(1139)
# No matches found in column: Survivor of Domestic Violence(341)
# No matches found in column: Enrollment CoC(10735)
# No matches found in column: City of Residence(1950)
# No matches found in column: County of Residence(1951)
# No matches found in column: Zip Code of Last Permanent Address(1136)
# No matches found in column: Prior Living Situation(43)
# No matches found in column: Length of Stay in Previous Place(1138)
# No matches found in column: On the night before did you stay on the streets, ES or SH?(12479)
# No matches found in column: Approximate date this episode of homelessness started(12480)
# No matches found in column: Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(12481)
# No matches found in column: Total number of months homeless on the street, in ES or SH in the past three years(12482)
# Processing sheet: INCOME ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Income (Entry)
# No matches found in column: Source of Income (Entry)
# No matches found in column: Monthly Income (Start)
# No matches found in column: Income Start Date (Entry)
# No matches found in column: Income End Date (Entry)
# No matches found in column: Provider (140-provider)
# No matches found in column: Date Added (140-date_added)
# Processing sheet: INCOME EXT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Income (Exit)
# No matches found in column: Source of Income (Exit)
# No matches found in column: Monthly Income Amount (Exit)
# No matches found in column: Income Start Date (Exit)
# No matches found in column: Income End Date (Exit)
# No matches found in column: Provider (140-provider)
# No matches found in column: Date Added (140-date_added)
# Processing sheet: NONCASH ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Benefit (Entry)
# No matches found in column: Non-Cash Source (Entry)
# No matches found in column: Non-Cash Start Date (Entry)
# No matches found in column: Non-Cash End Date (Entry)
# Processing sheet: NONCASH EXIT...
# No matches found in column: EE Provider
# No matches found in column: Receiving Benefit (Exit)
# No matches found in column: Non-Cash Source (Exit)
# No matches found in column: Non-Cash Amount (Exit)
# No matches found in column: Non-Cash Start Date (Exit)
# No matches found in column: Non-Cash End Date (Exit)
# Processing sheet: DISABILITY ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Disability Determination (Entry)
# No matches found in column: Disability Type (Entry)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Entry)
# No matches found in column: End Date(874)
# No matches found in column: Provider (417-provider)
# No matches found in column: Date Added (417-date_added)
# Processing sheet: DISABILITY EXIT...
# No matches found in column: EE Provider ID
# No matches found in column: Disability Determination (Exit)
# No matches found in column: Disability Type (Exit)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Exit)
# No matches found in column: Disability End Date (Exit)
# No matches found in column: Provider (417-provider)
# No matches found in column: Date Added (417-date_added)
# Processing sheet: PROVIDER...
# No matches found in column: EE Provider ID
# No matches found in column: CoC Code
#
# 🔍 Match found!
# Program: 11495
# Sheet: PROVIDER
# Column: Program Type Code
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                    Program Type Code
# 0  PH - Permanent Supportive Housing (disability ...
# 1  PH - Permanent Supportive Housing (disability ...
# 2  PH - Permanent Supportive Housing (disability ...
# No matches found in column: Provider County
# Processing sheet: Additional Info...
# No matches found in column: Unnamed: 0
# No matches found in column: Unnamed: 1
# Processing sheet: ENTRY-EXIT...
# No matches found in column: EE Provider ID
# No matches found in column: Entry Date
# No matches found in column: Housing Move-in Date(12855)
# No matches found in column: Exit Date
# No matches found in column: Destination
# No matches found in column: Reason for Leaving
# No matches found in column: Entry Exit Type
# No matches found in column: Entry Exit Date Added
# No matches found in column: Entry Exit User Creating
# No matches found in column: Entry Exit Date Updated
# No matches found in column: Entry Exit User Updating
# Processing sheet: EE REVIEWS...
# No matches found in column: EE Provider ID
# No matches found in column: Entry Exit Review Date
# No matches found in column: Entry Exit Review Uid
# No matches found in column: Entry Exit Review Point in Time Type
# No matches found in column: Entry Exit Review Type
# No matches found in column: Entry Exit Review Provider Updating
# No matches found in column: Entry Exit Review Date Updated
# No matches found in column: Entry Exit Review User Updating
# Processing sheet: EE UDES...
# No matches found in column: EE Provider ID
# No matches found in column: Relationship to Head of Household(10731)
# No matches found in column: Housing Status(6209)
# No matches found in column: Does the client have a disabling condition?(1139)
# No matches found in column: Survivor of Domestic Violence(341)
# No matches found in column: Enrollment CoC(10735)
# No matches found in column: City of Residence(1950)
# No matches found in column: County of Residence(1951)
# No matches found in column: Zip Code of Last Permanent Address(1136)
# No matches found in column: Prior Living Situation(43)
# No matches found in column: Length of Stay in Previous Place(1138)
# No matches found in column: On the night before did you stay on the streets, ES or SH?(12479)
# No matches found in column: Approximate date this episode of homelessness started(12480)
# No matches found in column: Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(12481)
# No matches found in column: Total number of months homeless on the street, in ES or SH in the past three years(12482)
# Processing sheet: INCOME ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Income (Entry)
# No matches found in column: Source of Income (Entry)
# No matches found in column: Monthly Income (Start)
# No matches found in column: Income Start Date (Entry)
# No matches found in column: Income End Date (Entry)
#
# 🔍 Match found!
# Program: Erin Park
# Sheet: INCOME ENT
# Column: Provider (140-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                               Provider (140-provider)
# 95  Community Housing Network - Oakland County - R...
# No matches found in column: Date Added (140-date_added)
# Processing sheet: INCOME EXT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Income (Exit)
# No matches found in column: Source of Income (Exit)
# No matches found in column: Monthly Income Amount (Exit)
# No matches found in column: Income Start Date (Exit)
# No matches found in column: Income End Date (Exit)
#
# 🔍 Match found!
# Program: Erin Park
# Sheet: INCOME EXT
# Column: Provider (140-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (140-provider)
# 109  Community Housing Network - Oakland County - R...
# No matches found in column: Date Added (140-date_added)
# Processing sheet: NONCASH ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Benefit (Entry)
# No matches found in column: Non-Cash Source (Entry)
# No matches found in column: Non-Cash Start Date (Entry)
# No matches found in column: Non-Cash End Date (Entry)
# Processing sheet: NONCASH EXIT...
# No matches found in column: EE Provider
# No matches found in column: Receiving Benefit (Exit)
# No matches found in column: Non-Cash Source (Exit)
# No matches found in column: Non-Cash Amount (Exit)
# No matches found in column: Non-Cash Start Date (Exit)
# No matches found in column: Non-Cash End Date (Exit)
# Processing sheet: DISABILITY ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Disability Determination (Entry)
# No matches found in column: Disability Type (Entry)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Entry)
# No matches found in column: End Date(874)
# No matches found in column: Provider (417-provider)
# No matches found in column: Date Added (417-date_added)
# Processing sheet: DISABILITY EXIT...
# No matches found in column: EE Provider ID
# No matches found in column: Disability Determination (Exit)
# No matches found in column: Disability Type (Exit)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Exit)
# No matches found in column: Disability End Date (Exit)
# No matches found in column: Provider (417-provider)
# No matches found in column: Date Added (417-date_added)
# Processing sheet: PROVIDER...
# No matches found in column: EE Provider ID
# No matches found in column: CoC Code
# No matches found in column: Program Type Code
# No matches found in column: Provider County
# Processing sheet: Additional Info...
# No matches found in column: Unnamed: 0
# No matches found in column: Unnamed: 1
# Processing sheet: ENTRY-EXIT...
# No matches found in column: EE Provider ID
# No matches found in column: Entry Date
# No matches found in column: Housing Move-in Date(12855)
# No matches found in column: Exit Date
# No matches found in column: Destination
# No matches found in column: Reason for Leaving
# No matches found in column: Entry Exit Type
# No matches found in column: Entry Exit Date Added
# No matches found in column: Entry Exit User Creating
# No matches found in column: Entry Exit Date Updated
# No matches found in column: Entry Exit User Updating
# Processing sheet: EE REVIEWS...
# No matches found in column: EE Provider ID
# No matches found in column: Entry Exit Review Date
# No matches found in column: Entry Exit Review Point in Time Type
# No matches found in column: Entry Exit Review Type
# No matches found in column: Entry Exit Review Provider Updating
# No matches found in column: Entry Exit Review Date Updated
# No matches found in column: Entry Exit Review User Updating
# Processing sheet: EE UDES...
# No matches found in column: EE Provider ID
# No matches found in column: Client Date of Birth(893)
# No matches found in column: Relationship to Head of Household(10731)
# No matches found in column: Housing Status(6209)
# No matches found in column: Does the client have a disabling condition?(1139)
# No matches found in column: Survivor of Domestic Violence(341)
# No matches found in column: Enrollment CoC(10735)
# No matches found in column: City of Residence(1950)
# No matches found in column: County of Residence(1951)
# No matches found in column: Zip Code of Last Permanent Address(1136)
# No matches found in column: Prior Living Situation(43)
# No matches found in column: Length of Stay in Previous Place(1138)
# No matches found in column: On the night before did you stay on the streets, ES or SH?(12479)
# No matches found in column: Approximate date this episode of homelessness started(12480)
# No matches found in column: Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(12481)
# No matches found in column: Total number of months homeless on the street, in ES or SH in the past three years(12482)
# Processing sheet: INCOME ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Income (Entry)
# No matches found in column: Source of Income (Entry)
# No matches found in column: Monthly Income (Start)
# No matches found in column: Income Start Date (Entry)
# No matches found in column: Income End Date (Entry)
# No matches found in column: Provider (140-provider)
# No matches found in column: Date Added (140-date_added)
# Processing sheet: INCOME EXT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Income (Exit)
# No matches found in column: Source of Income (Exit)
# No matches found in column: Monthly Income Amount (Exit)
# No matches found in column: Income Start Date (Exit)
# No matches found in column: Income End Date (Exit)
# No matches found in column: Provider (140-provider)
# No matches found in column: Date Added (140-date_added)
# Processing sheet: NONCASH ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Benefit (Entry)
# No matches found in column: Non-Cash Source (Entry)
# No matches found in column: Non-Cash Start Date (Entry)
# No matches found in column: Non-Cash End Date (Entry)
# Processing sheet: NONCASH EXIT...
# No matches found in column: EE Provider
# No matches found in column: Receiving Benefit (Exit)
# No matches found in column: Non-Cash Source (Exit)
# No matches found in column: Non-Cash Amount (Exit)
# No matches found in column: Non-Cash Start Date (Exit)
# No matches found in column: Non-Cash End Date (Exit)
# Processing sheet: DISABILITY ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Disability Determination (Entry)
# No matches found in column: Disability Type (Entry)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Entry)
# No matches found in column: End Date(874)
# No matches found in column: Provider (417-provider)
# No matches found in column: Date Added (417-date_added)
# Processing sheet: DISABILITY EXIT...
# No matches found in column: EE Provider ID
# No matches found in column: Disability Determination (Exit)
# No matches found in column: Disability Type (Exit)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Exit)
# No matches found in column: Disability End Date (Exit)
# No matches found in column: Provider (417-provider)
# No matches found in column: Date Added (417-date_added)
# Processing sheet: PROVIDER...
# No matches found in column: EE Provider ID
# No matches found in column: CoC Code
# No matches found in column: Program Type Code
# No matches found in column: Provider County
# Processing sheet: Additional Info...
# No matches found in column: Unnamed: 0
# No matches found in column: Unnamed: 1
# Processing sheet: ENTRY-EXIT...
# No matches found in column: EE Provider ID
# No matches found in column: Entry Date
# No matches found in column: Housing Move-in Date(12855)
# No matches found in column: Exit Date
# No matches found in column: Destination
# No matches found in column: Reason for Leaving
# No matches found in column: Entry Exit Type
# No matches found in column: Entry Exit Date Added
# No matches found in column: Entry Exit User Creating
# No matches found in column: Entry Exit Date Updated
# No matches found in column: Entry Exit User Updating
# Processing sheet: EE REVIEWS...
# No matches found in column: EE Provider ID
# No matches found in column: Entry Exit Review Date
# No matches found in column: Entry Exit Review Point in Time Type
# No matches found in column: Entry Exit Review Type
# No matches found in column: Entry Exit Review Provider Updating
# No matches found in column: Entry Exit Review Date Updated
# No matches found in column: Entry Exit Review User Updating
# Processing sheet: EE UDES...
# No matches found in column: EE Provider ID
# No matches found in column: Relationship to Head of Household(10731)
# No matches found in column: Housing Status(6209)
# No matches found in column: Does the client have a disabling condition?(1139)
# No matches found in column: Survivor of Domestic Violence(341)
# No matches found in column: Enrollment CoC(10735)
# No matches found in column: City of Residence(1950)
# No matches found in column: County of Residence(1951)
# No matches found in column: Zip Code of Last Permanent Address(1136)
# No matches found in column: Prior Living Situation(43)
# No matches found in column: Length of Stay in Previous Place(1138)
# No matches found in column: On the night before did you stay on the streets, ES or SH?(12479)
# No matches found in column: Approximate date this episode of homelessness started(12480)
# No matches found in column: Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(12481)
# No matches found in column: Total number of months homeless on the street, in ES or SH in the past three years(12482)
# Processing sheet: INCOME ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Income (Entry)
# No matches found in column: Source of Income (Entry)
# No matches found in column: Monthly Income (Start)
# No matches found in column: Income Start Date (Entry)
# No matches found in column: Income End Date (Entry)
#
# 🔍 Match found!
# Program: OC PATH
# Sheet: INCOME ENT
# Column: Provider (140-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (140-provider)
# 634  XXXCLOSED2019 - Community Housing Network - Oa...
# 640  XXXCLOSED2019 - Community Housing Network - Oa...
# 641  XXXCLOSED2019 - Community Housing Network - Oa...
# No matches found in column: Date Added (140-date_added)
# Processing sheet: INCOME EXT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Income (Exit)
# No matches found in column: Source of Income (Exit)
# No matches found in column: Monthly Income Amount (Exit)
# No matches found in column: Income Start Date (Exit)
# No matches found in column: Income End Date (Exit)
#
# 🔍 Match found!
# Program: OC PATH
# Sheet: INCOME EXT
# Column: Provider (140-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (140-provider)
# 652  XXXCLOSED2019 - Community Housing Network - Oa...
# 658  XXXCLOSED2019 - Community Housing Network - Oa...
# 701  Community Housing Network - Oakland County - R...
# No matches found in column: Date Added (140-date_added)
# Processing sheet: NONCASH ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Benefit (Entry)
# No matches found in column: Non-Cash Source (Entry)
# No matches found in column: Non-Cash Start Date (Entry)
# No matches found in column: Non-Cash End Date (Entry)
# Processing sheet: NONCASH EXIT...
# No matches found in column: EE Provider
# No matches found in column: Receiving Benefit (Exit)
# No matches found in column: Non-Cash Source (Exit)
# No matches found in column: Non-Cash Amount (Exit)
# No matches found in column: Non-Cash Start Date (Exit)
# No matches found in column: Non-Cash End Date (Exit)
# Processing sheet: DISABILITY ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Disability Determination (Entry)
# No matches found in column: Disability Type (Entry)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Entry)
# No matches found in column: End Date(874)
#
# 🔍 Match found!
# Program: OC PATH
# Sheet: DISABILITY ENT
# Column: Provider (417-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (417-provider)
# 398  Community Housing Network - Oakland County - R...
# 399  Community Housing Network - Oakland County - R...
# 406  Community Housing Network - Oakland County - R...
# No matches found in column: Date Added (417-date_added)
# Processing sheet: DISABILITY EXIT...
# No matches found in column: EE Provider ID
# No matches found in column: Disability Determination (Exit)
# No matches found in column: Disability Type (Exit)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Exit)
# No matches found in column: Disability End Date (Exit)
#
# 🔍 Match found!
# Program: OC PATH
# Sheet: DISABILITY EXIT
# Column: Provider (417-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (417-provider)
# 6    Community Housing Network - Oakland County - R...
# 239  Community Housing Network - Oakland County - R...
# 245  Community Housing Network - Oakland County - R...
# No matches found in column: Date Added (417-date_added)
# Processing sheet: PROVIDER...
# No matches found in column: EE Provider ID
# No matches found in column: CoC Code
# No matches found in column: Program Type Code
# No matches found in column: Provider County
# Processing sheet: Additional Info...
# No matches found in column: Unnamed: 0
# No matches found in column: Unnamed: 1
# Processing sheet: ENTRY-EXIT...
# No matches found in column: EE Provider ID
# No matches found in column: Entry Date
# No matches found in column: Housing Move-in Date(12855)
# No matches found in column: Exit Date
# No matches found in column: Destination
# No matches found in column: Reason for Leaving
# No matches found in column: Entry Exit Type
# No matches found in column: Entry Exit Date Added
# No matches found in column: Entry Exit User Creating
# No matches found in column: Entry Exit Date Updated
# No matches found in column: Entry Exit User Updating
# Processing sheet: EE REVIEWS...
# No matches found in column: EE Provider ID
# No matches found in column: Entry Exit Review Point in Time Type
# No matches found in column: Entry Exit Review Type
# No matches found in column: Entry Exit Review Provider Updating
# No matches found in column: Entry Exit Review Date Updated
# No matches found in column: Entry Exit Review User Updating
# Processing sheet: EE UDES...
# No matches found in column: EE Provider ID
# No matches found in column: Relationship to Head of Household(10731)
# No matches found in column: Housing Status(6209)
# No matches found in column: Does the client have a disabling condition?(1139)
# No matches found in column: Survivor of Domestic Violence(341)
# No matches found in column: Enrollment CoC(10735)
# No matches found in column: City of Residence(1950)
# No matches found in column: County of Residence(1951)
# No matches found in column: Zip Code of Last Permanent Address(1136)
# No matches found in column: Prior Living Situation(43)
# No matches found in column: Length of Stay in Previous Place(1138)
# No matches found in column: On the night before did you stay on the streets, ES or SH?(12479)
# No matches found in column: Approximate date this episode of homelessness started(12480)
# No matches found in column: Regardless of where they stayed last night - Number of times the client has been on the streets, in ES, or SH in the past three years including today(12481)
# No matches found in column: Total number of months homeless on the street, in ES or SH in the past three years(12482)
# Processing sheet: INCOME ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Income (Entry)
# No matches found in column: Source of Income (Entry)
# No matches found in column: Monthly Income (Start)
# No matches found in column: Income Start Date (Entry)
# No matches found in column: Income End Date (Entry)
#
# 🔍 Match found!
# Program: SPC
# Sheet: INCOME ENT
# Column: Provider (140-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (140-provider)
# 374  XXXCLOSED2019 - Community Housing Network - Oa...
# 495  Community Housing Network - Oakland County - R...
# 496  Community Housing Network - Oakland County - R...
# No matches found in column: Date Added (140-date_added)
# Processing sheet: INCOME EXT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Income (Exit)
# No matches found in column: Source of Income (Exit)
# No matches found in column: Monthly Income Amount (Exit)
# No matches found in column: Income Start Date (Exit)
# No matches found in column: Income End Date (Exit)
#
# 🔍 Match found!
# Program: SPC
# Sheet: INCOME EXT
# Column: Provider (140-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (140-provider)
# 500  Community Housing Network - Oakland County - R...
# 501  Community Housing Network - Oakland County - R...
# 503  Community Housing Network - Oakland County - R...
# No matches found in column: Date Added (140-date_added)
# Processing sheet: NONCASH ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Receiving Benefit (Entry)
# No matches found in column: Non-Cash Source (Entry)
# No matches found in column: Non-Cash Start Date (Entry)
# No matches found in column: Non-Cash End Date (Entry)
# Processing sheet: NONCASH EXIT...
# No matches found in column: EE Provider
# No matches found in column: Receiving Benefit (Exit)
# No matches found in column: Non-Cash Source (Exit)
# No matches found in column: Non-Cash Amount (Exit)
# No matches found in column: Non-Cash Start Date (Exit)
# No matches found in column: Non-Cash End Date (Exit)
# Processing sheet: DISABILITY ENT...
# No matches found in column: EE Provider ID
# No matches found in column: Disability Determination (Entry)
# No matches found in column: Disability Type (Entry)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Entry)
# No matches found in column: End Date(874)
#
# 🔍 Match found!
# Program: SPC
# Sheet: DISABILITY ENT
# Column: Provider (417-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (417-provider)
# 193  XXXCLOSED2019 - Community Housing Network - Oa...
# 265  Community Housing Network - Oakland County - R...
# 267  Community Housing Network - Oakland County - R...
# No matches found in column: Date Added (417-date_added)
# Processing sheet: DISABILITY EXIT...
# No matches found in column: EE Provider ID
# No matches found in column: Disability Determination (Exit)
# No matches found in column: Disability Type (Exit)
# No matches found in column: If Yes, Expected to be of long-continued and indefinite duration and substantially impairs ability to live independently(10678)
# No matches found in column: Disability Start Date (Exit)
# No matches found in column: Disability End Date (Exit)
#
# 🔍 Match found!
# Program: SPC
# Sheet: DISABILITY EXIT
# Column: Provider (417-provider)
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                Provider (417-provider)
# 201  XXXCLOSED2019 - Community Housing Network - Oa...
# 273  Community Housing Network - Oakland County - R...
# 275  Community Housing Network - Oakland County - R...
# No matches found in column: Date Added (417-date_added)
# Processing sheet: PROVIDER...
# No matches found in column: EE Provider ID
# No matches found in column: CoC Code
#
# 🔍 Match found!
# Program: SPC
# Sheet: PROVIDER
# Column: Program Type Code
# Rows matching any of the keywords Rapid Rehousing Program, Permanent Supportive Housing:
#                                    Program Type Code
# 0  PH - Permanent Supportive Housing (disability ...
# 1  PH - Permanent Supportive Housing (disability ...
# 2  PH - Permanent Supportive Housing (disability ...
# No matches found in column: Provider County

# %%
# Define the phrases to search for in the PROVIDER sheet
keywords = ["Rapid Re-Housing", "Permanent Supportive Housing"]

# Loop through each program
for program_id in program_ids:
    file_path = f"{base_dir}{program_id} RAW Client Data Export v3_EE Workflow.xlsx"
    
    if "TEMPLATE" in file_path.upper():
        continue
    if not os.path.exists(file_path):
        print(f"File not found for program {program_id}: {file_path}")
        continue

    try:
        # Read all sheets from the Excel file
        all_sheets = pd.read_excel(file_path, sheet_name=None, dtype=str)  # Read all sheets as strings

        # Get PROVIDER and ENTRY-EXIT sheets
        provider_df = all_sheets.get("PROVIDER", pd.DataFrame())
        entry_exit_df = all_sheets.get("ENTRY-EXIT", pd.DataFrame())

        # Check if the PROVIDER sheet contains the necessary columns
        if provider_df.empty:
            print(f"Program {program_id}: PROVIDER sheet is missing or empty.")
            continue

        # Filter rows in the PROVIDER sheet that contain either of the keywords
        provider_matches = provider_df[provider_df.apply(lambda row: row.astype(str).str.contains('|'.join(keywords), case=False, na=False).any(), axis=1)]

        if provider_matches.empty:
            print(f"Program {program_id}: No matching rows found in PROVIDER sheet.")
            continue

        # Get the indices of the matched rows from the PROVIDER sheet
        matching_indices = provider_matches.index

        # Filter the ENTRY-EXIT sheet based on the matching indices
        entry_exit_filtered = entry_exit_df.loc[matching_indices]

        # Combine PROVIDER and ENTRY-EXIT filtered rows into a single dataset
        combined_df = pd.concat([provider_matches, entry_exit_filtered], axis=1)

        # Save the combined dataset to a single sheet in Excel
        output_path = f"{program_id}_combined_filtered_data.xlsx"
        combined_df.to_excel(output_path, sheet_name="Filtered Data", index=False)

        print(f"Program {program_id}: Filtered data saved to {output_path}")

    except Exception as e:
        print(f"Error processing {file_path}: {e}")
# Out:
# Program 143: Filtered data saved to 143_combined_filtered_data.xlsx
# Program 1371 FINAL: Filtered data saved to 1371 FINAL_combined_filtered_data.xlsx
# Program 8319: Filtered data saved to 8319_combined_filtered_data.xlsx
# Program 11495: Filtered data saved to 11495_combined_filtered_data.xlsx
# Program Erin Park: No matching rows found in PROVIDER sheet.
# Program MC PATH: No matching rows found in PROVIDER sheet.
# Program OC PATH: No matching rows found in PROVIDER sheet.
# Program SPC: Filtered data saved to SPC_combined_filtered_data.xlsx

# %%
output_base_dir = "/Users/natika/Downloads/past semesters/CHN-Project/TableExtraction"

# %%
 #List of program IDs that had data saved
program_ids_with_data = ["143", "1371 FINAL", "8319", "11495", "SPC"]

# List to store DataFrames of all programs
all_program_data = []

# Loop through each program and read the corresponding dataset
for program_id in program_ids_with_data:
    file_path = os.path.join(output_base_dir, f"{program_id}_combined_filtered_data.xlsx")

    if os.path.exists(file_path):
        try:
            # Read the Excel file into a DataFrame
            df = pd.read_excel(file_path, sheet_name="Filtered Data")
            all_program_data.append(df)
            print(f"Program {program_id}: Data loaded successfully.")
        except Exception as e:
            print(f"Error reading {file_path}: {e}")
    else:
        print(f"File for Program {program_id} not found at {file_path}.")

# Combine all the DataFrames into one
combined_df = pd.concat(all_program_data, ignore_index=True)


combined_df.reset_index(drop=True, inplace=True)


combined_output_path = "/Users/natika/Downloads/past semesters/CHN-Project/days_to_movein.xlsx"
combined_df.to_excel(combined_output_path, index=False)

# Print confirmation
print(f"All datasets combined and saved to: {combined_output_path}")
# Out:
# Program 143: Data loaded successfully.
# Program 1371 FINAL: Data loaded successfully.
# Program 8319: Data loaded successfully.
# Program 11495: Data loaded successfully.
# Program SPC: Data loaded successfully.
# All datasets combined and saved to: /Users/natika/Downloads/past semesters/CHN-Project/days_to_movein.xlsx

# %%
combined_df['Entry Date'] = pd.to_datetime(combined_df['Entry Date'], errors='coerce')
combined_df['Housing Move-in Date'] = pd.to_datetime(combined_df['Housing Move-in Date(12855)'], errors='coerce')

# Create a new column for the duration (in days) between Entry Date and Housing Move-in Date
combined_df['Days_to_MoveIn'] = (combined_df['Housing Move-in Date'] - combined_df['Entry Date']).dt.days

# Display the first few rows of the dataframe to confirm the new column
print(combined_df[['Entry Date', 'Housing Move-in Date(12855)', 'Days_to_MoveIn']].head())
# Out:
#            Entry Date Housing Move-in Date(12855)  Days_to_MoveIn
# 0 2024-03-15 02:00:00         2024-03-15 12:00:00             0.0
# 1 2024-03-15 02:00:00         2024-03-15 12:00:00             0.0
# 2 2024-02-21 02:00:00         2024-03-09 12:00:00            17.0
# 3 2024-02-21 02:00:00         2024-03-09 12:00:00            17.0
# 4 2024-02-21 02:00:00         2024-03-09 12:00:00            17.0

# %%
new_dataset = combined_df[['Program Type Code', 'EE Provider ID', 'Days_to_MoveIn']]

# Display the first few rows of the new dataset
print(new_dataset.head())
# Out:
#                                    Program Type Code  \
# 0  PH - Permanent Supportive Housing (disability ...
# 1  PH - Permanent Supportive Housing (disability ...
# 2  PH - Permanent Supportive Housing (disability ...
# 3  PH - Permanent Supportive Housing (disability ...
# 4  PH - Permanent Supportive Housing (disability ...
#
#                                       EE Provider ID  Days_to_MoveIn
# 0  Community Housing Network, Inc. - Oakland Coun...             0.0
# 1  Community Housing Network, Inc. - Oakland Coun...             0.0
# 2  Community Housing Network, Inc. - Oakland Coun...            17.0
# 3  Community Housing Network, Inc. - Oakland Coun...            17.0
# 4  Community Housing Network, Inc. - Oakland Coun...            17.0

# %%
# Print the unique program types
print(new_dataset['Program Type Code'].unique())
# Out:
# ['PH - Permanent Supportive Housing (disability required for entry) (HUD)'
#  'PH - Rapid Re-Housing (HUD)']

# %%
new_dataset = df[['Program Type Code', 'EE Provider ID', 'Days_to_MoveIn']]


output_path = 'provider_move_in_data.xlsx'
new_dataset.to_excel(output_path, index=False)

# Display the first few rows of the new dataset
print(new_dataset.head())

# %%
# Group the dataset by 'Program Type Code' and calculate the average 'Days_to_MoveIn' for each program type
grouped_avg = new_dataset.groupby('Program Type Code')['Days_to_MoveIn'].mean()

print(grouped_avg)
# Out:
# Program Type Code
# PH - Permanent Supportive Housing (disability required for entry) (HUD)    55.662109
# PH - Rapid Re-Housing (HUD)                                                 3.325243
# Name: Days_to_MoveIn, dtype: float64

# %%
# Check unique values in 'Program Type Code' column
print(new_dataset['Program Type Code'].unique())
# Out:
# ['PH - Permanent Supportive Housing (disability required for entry) (HUD)']

# %%
# Map the average values back to the new dataset
new_dataset['Avg_Days_to_MoveIn'] = new_dataset['Program Type Code'].map(grouped_avg)

# Save the updated dataset to Excel
output_path = 'Avg_days_to_Movein.xlsx'
new_dataset.to_excel(output_path, index=False)

# Display the first few rows of the updated dataset
print(new_dataset.head())
# Out:
#                                    Program Type Code  \
# 0  PH - Permanent Supportive Housing (disability ...
# 1  PH - Permanent Supportive Housing (disability ...
# 2  PH - Permanent Supportive Housing (disability ...
# 3  PH - Permanent Supportive Housing (disability ...
# 4  PH - Permanent Supportive Housing (disability ...
#
#                                       EE Provider ID  Days_to_MoveIn  \
# 0  Community Housing Network, Inc. - Oakland Coun...             0.0
# 1  Community Housing Network, Inc. - Oakland Coun...             0.0
# 2  Community Housing Network, Inc. - Oakland Coun...            17.0
# 3  Community Housing Network, Inc. - Oakland Coun...            17.0
# 4  Community Housing Network, Inc. - Oakland Coun...            17.0
#
#    Avg_Days_to_MoveIn
# 0           55.662109
# 1           55.662109
# 2           55.662109
# 3           55.662109
# 4           55.662109
# /var/folders/yw/969dllhx7w9f5w_9rpxrq7280000gn/T/ipykernel_2575/3423982628.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataset['Avg_Days_to_MoveIn'] = new_dataset['Program Type Code'].map(grouped_avg)
